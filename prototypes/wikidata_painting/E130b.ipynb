# %% [markdown]
# ## Converting E130 from CSV into ShEx: mandatory/repeatable variant
#
# Links
# * https://github.com/dcmi/dcap/blob/master/prototypes/wikidata_painting/E130.ipynb - this notebook
# * https://www.wikidata.org/wiki/EntitySchema:E130 - Wikidata Entity Schema E130
#   * cached [in ShExC](https://github.com/dcmi/dcap/blob/master/prototypes/wikidata_painting/E130.shexc)
#   * cached [in ShExJ](https://github.com/dcmi/dcap/blob/master/prototypes/wikidata_painting/E130.shexj)
# * https://github.com/dcmi/dcap/blob/master/prototypes/wikidata_painting/E130.csv - CSV expression equivalent to E130
#
# This notebook documents a proof-of-concept script that takes a CSV expression of Wikidata Entity Schema E130 (a ShEx schema in ShExC syntax) and converts it from CSV back into ShExC syntax.

# %%
import csv
reader = csv.DictReader(open('E130b.csv', newline='', encoding='utf-8-sig'))
reader.fieldnames
# Out:
# ['Entity_name',
#  'Property',
#  'Property_label',
#  'Mand',
#  'Repeat',
#  'Value',
#  'Value_type',
#  'Annotation']

# %%
all_rows = [dict(row) for row in reader]
all_rows
# Out:
# [{'Entity_name': 'painting',
#   'Property': 'wdt:P31',
#   'Property_label': 'Is a',
#   'Mand': 'yes',
#   'Repeat': 'no',
#   'Value': 'wd:Q3305213',
#   'Value_type': 'URI',
#   'Annotation': 'Instance of "painting"'},
#  {'Entity_name': '',
#   'Property': 'wdt:P571',
#   'Property_label': 'Date of inception',
#   'Mand': 'no',
#   'Repeat': 'no',
#   'Value': '',
#   'Value_type': 'DateTime',
#   'Annotation': ''},
#  {'Entity_name': '',
#   'Property': 'wdt:P276',
#   'Property_label': 'Location',
#   'Mand': 'yes',
#   'Repeat': 'yes',
#   'Value': '',
#   'Value_type': '',
#   'Annotation': ''},
#  {'Entity_name': '',
#   'Property': 'wdt:P1476',
#   'Property_label': 'Title',
#   'Mand': 'yes',
#   'Repeat': 'yes',
#   'Value': '',
#   'Value_type': '',
#   'Annotation': ''},
#  {'Entity_name': '',
#   'Property': 'wdt:P195',
#   'Property_label': 'Collection',
#   'Mand': 'yes',
#   'Repeat': 'yes',
#   'Value': '',
#   'Value_type': '',
#   'Annotation': ''},
#  {'Entity_name': '',
#   'Property': 'wdt:P170',
#   'Property_label': 'Creator',
#   'Mand': 'yes',
#   'Repeat': 'yes',
#   'Value': 'creator',
#   'Value_type': 'Entity_name',
#   'Annotation': ''},
#  {'Entity_name': 'creator',
#   'Property': 'wdt:P31',
#   'Property_label': 'Is a',
#   'Mand': 'yes',
#   'Repeat': 'no',
#   'Value': 'wd:',
#   'Value_type': 'URIStem',
#   'Annotation': ''}]

# %%
prefixes = """PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>"""

# %%
end_matter = """}

# Proposed test for SPARQL - Top 25 paintings
# SELECT ?id WHERE { VALUES ?id { wd:Q12418 wd:Q45585 wd:Q175036 wd:Q29530 wd:Q185372 wd:Q219831 wd:Q151047 wd:Q208758 wd:Q25729 wd:Q154469 wd:Q474338 wd:Q328523 wd:Q321303 wd:Q1892 745 wd:Q334138 wd:Q1091086 wd:Q698487 wd:Q212616 wd:Q152509 wd:Q152867 wd:Q220859 wd:Q734834  } }"""

# %%
schema = []
start = ''
started = False
for row in all_rows:
    entity_name = row['Entity_name']
    property = row['Property']
    property_label = row['Property_label']
    mandatory = row['Mand']
    repeatable = row['Repeat']
    value = row['Value']           # Node Constraint
    value_type = row['Value_type'] # Node Constraint
    annotation = row['Annotation']
    vtype = ''
    if not start:
        if entity_name:
            start_node = entity_name
            start = f"""start = @<{start_node}>"""
            schema.append(f"{start}\n\n")
    if entity_name:
        if started:
            schema.append("}\n\n")
        shape_name = f"<{entity_name}>" + " {\n"
        schema.append(shape_name)
        started = True
    if property_label:
        schema.append(f"    # {repr(property_label)} {annotation}\n")
    if mandatory == "yes":
        if repeatable == "yes":
            card = '+'
        if repeatable == "no":
            card = ''
    if mandatory == "no":
        if repeatable == "no":
            card = '?'
    if value_type == "DateTime":
        vtype = " xsd:dateTime"
        schema.append(f"    {property}{vtype}{card} ;\n")
    elif value_type == "URIStem":
        value = value + "~"
        schema.append(f"    {property} [{value}] {card} ;\n")
    elif value_type == "Entity_name":
        value = f"@<{value}>"
        schema.append(f"    {property} {value}{card} ;\n")
    elif not value:
        schema.append(f"    {property} . {card} ;\n")
    elif value:
        schema.append(f"    {property} [{value}] {card} ;\n")

print(prefixes, "\n")
for line in schema:
    print(line, end="")
print("\n", end_matter)
# Out:
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# start = @<painting>
#
# <painting> {
#     # 'Is a' Instance of "painting"
#     wdt:P31 [wd:Q3305213]  ;
#     # 'Date of inception'
#     wdt:P571 xsd:dateTime? ;
#     # 'Location'
#     wdt:P276 . + ;
#     # 'Title'
#     wdt:P1476 . + ;
#     # 'Collection'
#     wdt:P195 . + ;
#     # 'Creator'
#     wdt:P170 @<creator>+ ;
# }
#
# <creator> {
#     # 'Is a'
#     wdt:P31 [wd:~]  ;
#
#  }
#
# # Proposed test for SPARQL - Top 25 paintings
# # SELECT ?id WHERE { VALUES ?id { wd:Q12418 wd:Q45585 wd:Q175036 wd:Q29530 wd:Q185372 wd:Q219831 wd:Q151047 wd:Q208758 wd:Q25729 wd:Q154469 wd:Q474338 wd:Q328523 wd:Q321303 wd:Q1892 745 wd:Q334138 wd:Q1091086 wd:Q698487 wd:Q212616 wd:Q152509 wd:Q152867 wd:Q220859 wd:Q734834  } }

# %% [markdown]
# ### Result
#
# The resulting schema (above) is identical with [Wikidata Entity Schema E130](https://www.wikidata.org/wiki/EntitySchema:E130).
#
# This can be tested by cut-and-pasting the schemas into [ShEx2 online parser](https://rawgit.com/shexSpec/shex.js/master/packages/shex-webapp/doc/shex-simple.html), leaving the data box blank, and running "validate".
# * E130 (ShExC) converted into ShExJ: [the result](https://github.com/dcmi/dcap/blob/master/prototypes/wikidata_painting/E130.shexj)
# * The ShExC schema generated above, converted into ShExJ: [the result](https://github.com/dcmi/dcap/blob/master/prototypes/wikidata_painting/E130.shexj_generated)

# %%
import pandas as pd
pd.read_csv('E130b.csv')
# Out:
#   Entity_name   Property     Property_label Mand Repeat        Value  \
# 0    painting    wdt:P31               Is a  yes     no  wd:Q3305213
# 1         NaN   wdt:P571  Date of inception   no     no          NaN
# 2         NaN   wdt:P276           Location  yes    yes          NaN
# 3         NaN  wdt:P1476              Title  yes    yes          NaN
# 4         NaN   wdt:P195         Collection  yes    yes          NaN
# 5         NaN   wdt:P170            Creator  yes    yes      creator
# 6     creator    wdt:P31               Is a  yes     no          wd:
#
#     Value_type              Annotation
# 0          URI  Instance of "painting"
# 1     DateTime                     NaN
# 2          NaN                     NaN
# 3          NaN                     NaN
# 4          NaN                     NaN
# 5  Entity_name                     NaN
# 6      URIStem                     NaN
